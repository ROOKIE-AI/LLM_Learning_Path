# %% [markdown]
# # Transformer深度解析

# %%
from transformer_base import *
# Out:
# Using device: cpu

# %%
# 可视化位置编码
visualize_positional_encoding()
# Out:
# ==================================================
# Positional Encoding Visualization
# ==================================================

# %%
# 可视化自注意力
visualize_self_attention()
# Out:
# ==================================================
# Self-Attention Visualization
# ==================================================

# %%
# 演示Transformer模型
demonstrate_transformer()
# 训练简单翻译模型
model, dataset = train_simple_transformer()
# 显示翻译示例
show_translation_examples(model, dataset)

print("\n" + "*"*70)
print("*" + " "*23 + "Transformer Implementation Complete" + " "*22 + "*")
print("*"*70)
# Out:
# ==================================================
# Transformer Demonstration
# ==================================================
# Transformer(
#   (encoder_embedding): Embedding(5000, 128)
#   (decoder_embedding): Embedding(5000, 128)
#   (encoder): Encoder(
#     (positional_encoding): PositionalEncoding()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (layers): ModuleList(
#       (0-1): 2 x EncoderLayer(
#         (self_attn): MultiHeadAttention(
#           (W_q): Linear(in_features=128, out_features=128, bias=True)
#           (W_k): Linear(in_features=128, out_features=128, bias=True)
#           (W_v): Linear(in_features=128, out_features=128, bias=True)
#           (W_o): Linear(in_features=128, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (linear1): Linear(in_features=128, out_features=512, bias=True)
#           (linear2): Linear(in_features=512, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): Decoder(
#     (positional_encoding): PositionalEncoding()
#     (dropout): Dropout(p=0.1, inplace=False)
#     (layers): ModuleList(
#       (0-1): 2 x DecoderLayer(
#         (self_attn): MultiHeadAttention(
#           (W_q): Linear(in_features=128, out_features=128, bias=True)
#           (W_k): Linear(in_features=128, out_features=128, bias=True)
#           (W_v): Linear(in_features=128, out_features=128, bias=True)
#           (W_o): Linear(in_features=128, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (cross_attn): MultiHeadAttention(
#           (W_q): Linear(in_features=128, out_features=128, bias=True)
#           (W_k): Linear(in_features=128, out_features=128, bias=True)
#           (W_v): Linear(in_features=128, out_features=128, bias=True)
#           (W_o): Linear(in_features=128, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (feed_forward): FeedForward(
#           (linear1): Linear(in_features=128, out_features=512, bias=True)
#           (linear2): Linear(in_features=512, out_features=128, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (final_layer): Linear(in_features=128, out_features=5000, bias=True)
# )
#
# 执行前向传播...
# 输入源序列形状: torch.Size([2, 10])
# 输入目标序列形状: torch.Size([2, 8])
# 输出序列形状: torch.Size([2, 8, 5000])
# 输出第一个样本的第一个时间步的前5个logits: tensor([-0.3801,  0.1682,  0.2639,  0.0254,  0.0783], grad_fn=<SliceBackward0>)
#
# ==================================================
# Training Simple Translation Task
# ==================================================
# 训练集大小: 800
# 测试集大小: 200
# 英文词汇量: 19
# 中文词汇量: 18
# Epoch 1/5, Batch 10/13, Loss: 2.5947
# Epoch 1/5, Train Loss: 2.7354, Test Loss: 2.4407
# Epoch 2/5, Batch 10/13, Loss: 2.2916
# Epoch 2/5, Train Loss: 2.3707, Test Loss: 2.1531
# Epoch 3/5, Batch 10/13, Loss: 2.0558
# Epoch 3/5, Train Loss: 2.1216, Test Loss: 1.8906
# Epoch 4/5, Batch 10/13, Loss: 1.8219
# Epoch 4/5, Train Loss: 1.8751, Test Loss: 1.6362
# Epoch 5/5, Batch 10/13, Loss: 1.6154
# Epoch 5/5, Train Loss: 1.6331, Test Loss: 1.3992
# Training visualization saved as transformer_training.png
#
# ==================================================
# Translation Examples
# ==================================================
# 源文本: <sos> 3 minus 4 equals <eos>
# 目标翻译: <sos> 3 减 4 等于 <eos>
# 模型翻译: 3 等于 4 等于 <eos> <eos> <eos> <eos> <eos>
# --------------------------------------------------
# 源文本: <sos> 9 divided by 3 equals 3 <eos>
# 目标翻译: <sos> 9 除以 3 等于 3 <eos>
# 模型翻译: 3 等于 3 等于 <eos> 等于 <eos> <eos> <eos>
# --------------------------------------------------
# 源文本: <sos> 5 divided by 4 equals 1 <eos>
# 目标翻译: <sos> 5 除以 4 等于 1 <eos>
# 模型翻译: 1 除以 5 等于 1 <eos> <eos> 1 1
# --------------------------------------------------
# 源文本: <sos> 6 minus 2 equals 4 <eos>
# 目标翻译: <sos> 6 减 2 等于 4 <eos>
# 模型翻译: 2 等于 4 等于 <eos> 等于 <eos> <eos> <eos>
# --------------------------------------------------
# 源文本: <sos> 3 times 1 equals 3 <eos>
# 目标翻译: <sos> 3 乘 1 等于 3 <eos>
# 模型翻译: 3 等于 3 等于 <eos> <eos> <eos> <eos> <eos>
# --------------------------------------------------
#
# **********************************************************************
# *                       Transformer Implementation Complete                      *
# **********************************************************************
